# %%
import pandas as pd

# %%
df = pd.read_csv("mada_illumina_guuids.csv")

# %%
df
# Out:
#           Id Sample  Source Date extraction  \
# 0        Mada-P201S  Sputum        26/11/19
# 1       Mada-P202S   Sputum        26/11/19
# 2       Mada-P203S   Sputum         7/10/19
# 3        Mada-P204S  Sputum        26/11/19
# 4       Mada-P205S   Sputum        26/11/19
# ..              ...     ...             ...
# 77   Mada-P227S_r_1  Sputum         26/9/19
# 78  Mada-P228S_r_1   Sputum         26/9/19
# 79  Mada-P229S_r_1   Sputum         8/10/19
# 80   Mada-P206S_r_1  Sputum        17/10/19
# 81  Mada-P222S_r_1   Sputum        22/10/19
#
#                                     guid Reference Genome  \
# 0   a7563adf-562d-458e-959a-1d7de9cb16d1        R00000039
# 1   c8903173-fa62-40ef-938d-b2f3bc2ded7a        R00000039
# 2   6b45dd89-fd62-4c7c-8a11-3ba342f49484        R00000039
# 3   58c59cd2-6749-4508-8d10-b8d9117f1c0c        R00000039
# 4   1533e371-e622-41fe-a253-d90ef46c15cd        R00000039
# ..                                   ...              ...
# ...
